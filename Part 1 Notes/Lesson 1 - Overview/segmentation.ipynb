# %%
# %pip install fastbook
# Out:
# Requirement already satisfied: fastbook in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (0.0.29)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pip in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (23.3.1)
# Requirement already satisfied: packaging in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (23.2)
# Requirement already satisfied: fastai>=2.6 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (2.7.14)
# Requirement already satisfied: graphviz in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (0.20.1)
# Requirement already satisfied: pandas in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (2.2.0)
# Requirement already satisfied: requests in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (2.31.0)
# Requirement already satisfied: transformers in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (4.37.2)
# Requirement already satisfied: datasets in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (2.17.0)
# Requirement already satisfied: ipywidgets<8 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (7.8.1)
# Requirement already satisfied: sentencepiece in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastbook) (0.1.99)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (0.17.0)
# Requirement already satisfied: matplotlib in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (3.8.2)
# Requirement already satisfied: pyyaml in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (10.2.0)
# Requirement already satisfied: scikit-learn in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (1.4.0)
# Requirement already satisfied: scipy in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (1.12.0)
# Requirement already satisfied: spacy<4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (3.7.2)
# Requirement already satisfied: torch<2.3,>=1.10 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fastai>=2.6->fastbook) (2.2.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (5.14.1)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (8.21.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipywidgets<8->fastbook) (1.1.7)
# Requirement already satisfied: filelock in c:\users\ratti\appdata\roaming\python\python311\site-packages (from datasets->fastbook) (3.12.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (1.26.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (0.3.8)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (4.66.2)
# Requirement already satisfied: xxhash in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (0.70.16)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets->fastbook) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from datasets->fastbook) (0.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from requests->fastbook) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from requests->fastbook) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from requests->fastbook) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from requests->fastbook) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from pandas->fastbook) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from pandas->fastbook) (2023.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from transformers->fastbook) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from transformers->fastbook) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from transformers->fastbook) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from aiohttp->datasets->fastbook) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from aiohttp->datasets->fastbook) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from aiohttp->datasets->fastbook) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from aiohttp->datasets->fastbook) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from huggingface-hub>=0.19.4->datasets->fastbook) (4.9.0)
# Requirement already satisfied: decorator in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.2)
# Requirement already satisfied: colorama in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from python-dateutil>=2.8.2->pandas->fastbook) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.6.1)
# Requirement already satisfied: jinja2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.3.0)
# Requirement already satisfied: sympy in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from torch<2.3,>=1.10->fastai>=2.6->fastbook) (1.12)
# Requirement already satisfied: networkx in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from torch<2.3,>=1.10->fastai>=2.6->fastbook) (3.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (3.1.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (3.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.25.2)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.0.12)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.3.3)
# Requirement already satisfied: wcwidth in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.13)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (2.16.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from sympy->torch<2.3,>=1.10->fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.5.2)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.16.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.9.2)
# Requirement already satisfied: overrides in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.7.0)
# Requirement already satisfied: prometheus-client in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.19.0)
# Requirement already satisfied: pywinpty in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.0.12)
# Requirement already satisfied: pyzmq>=24 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.18.0)
# Requirement already satisfied: websocket-client in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.29.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.2.2)
# Requirement already satisfied: babel>=2.10 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.21.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.17.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ratti\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.19.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.9.0)
# Requirement already satisfied: webencodings in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.4)
# Requirement already satisfied: uri-template in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.5)
# Requirement already satisfied: pycparser in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ratti\anaconda3\envs\fastai\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.8.19.20240106)

# %%
from fastcore.all import *
from fastbook import *

# %%
path = untar_data(URLs.CAMVID_TINY)
path.ls()
# Out:
# (#3) [Path('C:/Users/ratti/.fastai/data/camvid_tiny/codes.txt'),Path('C:/Users/ratti/.fastai/data/camvid_tiny/images'),Path('C:/Users/ratti/.fastai/data/camvid_tiny/labels')]

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)
codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole', 'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter',
#        'OtherMoving', 'ParkingBlock', 'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone', 'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel',
#        'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
fnames = get_image_files(path/"images")
fnames[0]
# Out:
# Path('C:/Users/ratti/.fastai/data/camvid_tiny/images/0001TP_006750.png')

# %%
(path/"labels").ls()[0]
# Out:
# Path('C:/Users/ratti/.fastai/data/camvid_tiny/labels/0001TP_006750_P.png')

# %%
def label_func(fn): return path/"labels"/f"{fn.stem}_P{fn.suffix}"

# %%
dls = SegmentationDataLoaders.from_label_func(
    path, bs=8, fnames = fnames, label_func = label_func, codes = codes
)

# %%
dls.show_batch()

# %%
learn = unet_learner(dls, resnet34)
learn.fine_tune(12)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.094566</td>
#       <td>3.701073</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.184106</td>
#       <td>2.084216</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.886824</td>
#       <td>1.383157</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.643811</td>
#       <td>1.242906</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.466398</td>
#       <td>1.384265</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.325095</td>
#       <td>1.004058</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.196827</td>
#       <td>0.849960</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.077041</td>
#       <td>0.801932</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.974439</td>
#       <td>0.747366</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.888188</td>
#       <td>0.740931</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.816157</td>
#       <td>0.717011</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.755914</td>
#       <td>0.722527</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.707571</td>
#       <td>0.716774</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(max_n=6, figsize=(10,20))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
